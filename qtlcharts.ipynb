# %%
library(qtlcharts)
library(htmlwidgets)
library(IRdisplay)
library(glue)
library(qtl)

# %%
if(!dir.exists("html")) dir.create("html")

# %%
data(grav)

grav$pheno <- grav$pheno[,seq(1, nphe(grav), by=5)]
times <- as.numeric(sub("T", "", colnames(grav$pheno)))/60

grav <- calc.genoprob(grav, step=1)
out.hk <- scanone(grav, phe=1:nphe(grav), method="hk")

# %%
file <- "html/iplot_demo.html"
height <- 500
width <- 700

h <- iplot(grav$pheno[,1], grav$pheno[,25], 
           chartOpts=list(xlab=phenames(grav)[1], ylab=phenames(grav)[25],
                          height=height, width=width))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# Set screen size to height=700 x width=1000
# <iframe src="html/iplot_demo.html" height="600px" width="800px"></iframe>

# %%
file <- "html/iplotMap_demo.html"
height <- 700
width <- 850

h <- iplotMap(pull.map(grav), chartOpts=list(height=height, width=width))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/iplotMap_demo.html" height="800px" width="950px"></iframe>

# %%
file <- "html/iboxplot_demo.html"
height <- 680
width <- 850

h <- iboxplot(t(grav$pheno), breaks=51, orderByMedian=FALSE, 
             chartOpts=list(xlab="Time index", ylab="Root tip angle (degrees)",
                           height=height, width=width))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/iboxplot_demo.html" height="780px" width="950px"></iframe>

# %%
file <- "html/iheatmap_demo.html"
height <- 650
width <- 850

n <- 101                                                                                                                                                      
x <- y <- seq(-2, 2, len=n)                                                                                                                                   
z <- matrix(ncol=n, nrow=n)                                                                                                                                   
for(i in seq(along=x))                                                                                                                                        
    for(j in seq(along=y))                                                                                                                                    
        z[i,j] <- x[i]*y[j]*exp(-x[i]^2 - y[j]^2)                                                                                                             
h <- iheatmap(z, x, y, chartOpts=list(height=height, width=width)) 

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/iheatmap_demo.html" height="750px" width="950px"></iframe>

# %%
file <- "html/iplotCorr_demo.html"
height <- 400
width <- 850

h <- iplotCorr(grav$pheno,
              chartOpts=list(height=height, width=width))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/iplotCorr_demo.html" height="500px" width="950px"></iframe>

# %%
file <- "html/iplotCurves_demo.html"
height <- 650
width <- 850

h <- iplotCurves(grav$pheno, times,
                 grav$pheno[,c("T30", "T240")],
                 grav$pheno[,c("T240", "T480")],
                 chartOpts=list(curves_xlab="Time", curves_ylab="Root tip angle",
                                scat1_xlab="Angle at 30 min", scat1_ylab="Angle at 4 hrs",
                                scat2_xlab="Angle at 4 hrs", scat2_ylab="Angle at 8 hrs",
                               height=height, width=width))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/iplotCurves_demo.html" height="750px" width="950px"></iframe>

# %%
file <- "html/iplotMScanone_demo.html"
height <- 800
width <- 800

h <- iplotMScanone(out.hk, grav, 
                   chartOpts=list(eff_ylab="QTL effect",
                                 height=height, width=width))


saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/iplotMScanone_demo.html" height="900px" width="900px"></iframe>

# %%
file <- "html/iplotPXG_demo.html"
height <- 400
width <- 800

h <- iplotPXG(grav, "BF.206L-Col", "T310",
              chartOpts=list(horizontal=TRUE, height=height, width=width))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/iplotPXG_demo.html" height="500px" width="900px"></iframe>

# %%
file <- "html/idotplot_demo.html"
height <- 400
width <- 800

h <- idotplot(pull.geno(grav)[, "BF.206L-Col"], grav$pheno[,"T310"],
              chartOpts=list(horizontal=TRUE, height=height, width=width,
                             ylab="Phenotype", xlab="Genotype"))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/idotplot_demo.html" height="500px" width="900px"></iframe>

# %%
file <- "html/iplotRF_demo.html"
height <- 800
width <- 800

grav <- est.rf(grav)
h <- iplotRF(grav, chr=c(1,4))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/iplotRF_demo.html" height="900px" width="900px"></iframe>

# %%
file <- "html/iplotScanone_noeff_demo.html"
height <- 400
width <- 800

h <- iplotScanone(out.hk, lod=match("T310", names(grav$pheno)),
                  chartOpts=list(height=height, width=width))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/iplotScanone_noeff_demo.html" height="500px" width="900px"></iframe>

# %%
file <- "html/iplotScanone_ci_demo.html"
height <- 400
width <- 800

h <- iplotScanone(out.hk, grav, lod=match("T310", names(grav$pheno)), phe="T310",
                  chartOpts=list(height=height, width=width))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/iplotScanone_ci_demo.html" height="500px" width="900px"></iframe>

# %%
file <- "html/iplotScanone_pxg_demo.html"
height <- 400
width <- 800

h <- iplotScanone(out.hk, grav, lod=match("T310", names(grav$pheno)), phe="T310",
                  pxgtype="raw", chartOpts=list(height=height, width=width))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/iplotScanone_pxg_demo.html" height="500px" width="900px"></iframe>

# %%
file <- "html/iplotScantwo_demo.html"
height <- 800
width <- 800

out2 <- scantwo(grav, chr=1, phe="T310", method="hk")

h <- iplotScantwo(out2, grav, phe="T310",
                  chartOpts=list(height=height, width=width))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
#  --Running scanone
#  --Running scantwo
#  (1,1)
# <iframe src="html/iplotScantwo_demo.html" height="900px" width="900px"></iframe>

# %%
set.seed(69891250)                                                                                                                                            
p <- 500                                                                                                                                                      
n <- 300                                                                                                                                                      
SD <- runif(p, 1, 5)                                                                                                                                          
r <- runif(p, -1, 1)                                                                                                                                          
scat2 <- vector("list", p)                                                                                                                                    
for(i in 1:p)                                                                                                                                                 
   scat2[[i]] <- matrix(rnorm(2*n), ncol=2) %*% chol(SD[i]^2*matrix(c(1, r[i], r[i], 1), ncol=2))                                                             
scat1 <- cbind(SD=SD, r=r)   

width <- 800
height <- 400
file <- "html/scat2scat_demo.html"

h <- scat2scat(scat1, scat2, chartOpts=list(width=width, height=height))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/scat2scat_demo.html" height="500px" width="900px"></iframe>

# %%
data(fake.f2)
g <- pull.geno(fake.f2, chr=1:19)
p <- apply(g, 1, function(a) table(factor(a, levels=1:3)))
p <- t(p)/colSums(p)
colnames(p) <- c("AA", "AB", "BB")
           
file <- "html/itriplot_demo.html"
height <- 500
width <- 500

h <- itriplot(p, chartOpts=list(height=height, width=width))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/itriplot_demo.html" height="600px" width="600px"></iframe>

# %%
file <- "html/ipleiotropy_demo.html"
height <- 400
width <- 800

h <- ipleiotropy(grav, out.hk, phe=c(1, 25), lod=c(1, 25),
                 chartOpts=list(height=height, width=width))

saveWidget(h, file, selfcontained=TRUE)
html <- glue('<iframe src="{file}" height="{height+100}px" width="{width+100}px"></iframe>')
display_html(html)
# Out:
# <iframe src="html/ipleiotropy_demo.html" height="500px" width="900px"></iframe>
